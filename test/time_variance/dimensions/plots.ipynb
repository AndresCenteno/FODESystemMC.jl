# %%
using Pkg; Pkg.add("LaTeXStrings")
# Out:
#    Resolving package versions...
#     Updating `~/Documents/FODESystemMC.jl/Project.toml`
#   [b964fa9f] + LaTeXStrings v1.3.1
#   No Changes to `~/Documents/FODESystemMC.jl/Manifest.toml`

# %%
using Plots
using Statistics
using DelimitedFiles
using LaTeXStrings

# %%
xlab = "nx"
xvec = 1:5
xticks = 1:5
# Out:
# 1:5

# %%
exp = readdlm("augmenting_dims.csv");

# %%
exp
# Out:
# 9×5 Matrix{Float64}:
#     1.0            2.0            3.0            4.0          0.0
#     0.115537       0.100088       0.0674277      0.0391075    0.0
#     0.00440785     4.93292e-5     6.41919e-7     9.97073e-9   0.0
#   112.774         26.1635         3.79147        0.451144     0.0
#     0.139012       0.0270092      0.00460818     0.000771024  0.0
#  1404.96        3395.96        4002.54        3521.4          0.0
#     4.10525e6      4.85572e6      1.14442e7      2.41665e7    0.0
#     5.1565e5       9.68114e5      2.32438e6      5.53872e6    0.0
#     4.13042e6      8.42387e6      2.35754e7      3.99279e7    0.0

# %%
plot(1:4,exp[2:end-5,1:end-1]',xlabel="Dimension",
ylabel="Mean variance",title="1e3 particles",labels=["u(T)" L"\partial A" L"\partial \alpha" L"\partial u_0"])

# %%
plot(range(0.1,0.9,9),mean_alpha_exp[2:6,:]',xlabel=L"\alpha",
ylabel="Mean variance",title="1e3 particles over 40 random experiments",labels=["u(T)" L"\partial A" L"\partial \alpha" L"\partial u_0" L"\partial T"])
savefig("alpha/variance_alpha_with_time.png")
# Out:
# "/home/aner/Documents/FODESystemMC.jl/test/time_variance/alpha/variance_alpha_with_time.png"

# %%
plot(range(0.1,0.9,9),mean_alpha_exp[7:9,:]',xlabel=L"\alpha",
ylabel="Mean time (nanoseconds)",title="1e3 particles over 40 random experiments",labels=["0.95 quantile" "0.05 quantile" "Mean time"])

# %%
savefig("alpha/time.png")
# Out:
# "/home/aner/Documents/FODESystemMC.jl/test/time_variance/alpha/time.png"
